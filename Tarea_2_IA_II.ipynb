# %% [markdown]
# # **Tarea #2: Regresión lineal simple usando TensorFlow en Python**
#
# # Universidad de Monterrey
#
# * Estudiante: Jonathan A. Valadez Saldaña
#
# * Materia: Inteligencia Artificial II
#
# * Profesor:  Andrés Hernández
#
# 30/Agosto/2024 - San Pedro Garza García, N.L.

# %% [markdown]
# Siempre cuando se empieza un código en python es importante importar las librerías que vayamos a ocupar para nuestro programa, en este caso usamos las siguientes librerías que cuentan con las siguientes características:
# * Numpy: Nos ayuda a realizar operaciones matemáticas
# * Tensorflow: Nos permite el desarrollo de redes neuronales
# * Matplotlib: Visualización  gráfica de datos
# * Sklearn.model_selection: Nos permite dividir los datos de entrenamiento y los de prueba

# %%
#Importamos librerías
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %% [markdown]
# Creamos una función llamada 'generate_data' que trae como parámetros de entrada lo siguiente:
# * true_coeffs: Asigamos el número de coeficientes que tendrá nuestro modelo
# * noise_std: Le agregamos un ruido con una desviación estándar  de 2
# * num_samples: El número total de los datos que queremos generar o registrar
#
# Posteriormente, para poder replicar el experimento y trabajar con el mismo conjunto de datos, usamos una semilla de aleatoriedad, es decir, vamos a generar un conjunto de datos aleatorios únicos, y solo con ese conjunto vamos a desarrollar nuestro modelo, de manera que podamos probar al mismo múltiples veces con los mismos datos generados.
#
# Ahora bien, para poder visualizar estos datos en una gráfica 2D ocupamos generar sus coordenadas X y Y, las cuales pueden ser como nosotros queramos. Para este caso X va estar en un rango entre 0 y el número de datos, que son 100, mientras que para Y tenemos una ecuación que hace uso de los coeficientes del parámetro de entrada, de los valores de X y datos aleatorios. Todo esto representado en la ecuación que se encuentra en el código. Una vez hecho todo esto en la función 'generate_data' devolvemos los valores de X y Y como parámetros de salida.

# %%
# Generamos dataset
def generate_data(true_coeffs=np.array([10, 1]), noise_std=2, num_samples=100):

    # Semilla de reproducibilidad
    np.random.seed(4500)

    # Generamos datos sintéticos
    x = np.arange(0, 100, 1)
    y = true_coeffs[0] + true_coeffs[1]*x + np.random.normal(loc=0.0, scale=noise_std, size=num_samples)

    # Devolvemos características y respuesta
    return(x, y)

# %% [markdown]
# Aquí solo se definen los parámetros de entrada y hacemos un llamado a la función 'generate_data'

# %%
# Generamos datos sintéticos para nuestra regresión lineal
true_coeffs=np.array([10, 1])
noise_std = 5
x, y = generate_data(true_coeffs=true_coeffs, noise_std=noise_std, num_samples=100)

# %% [markdown]
# Ya hecha la llamada de la función y generado la salida de esta, es momento de visualizar el resultado obtenido. Para toda la visualización de los datos vamos a estar usando la librería que definimos como 'plt' y llamando diferentes métodos que nos permitan configurar diferentes partes de nuestra gráfica.
#
# Comenzamos  definiendo las dimensiones de nuestra gráfica, donde se llama  el método 'figure' para darle las dimensiones que tendrá nuestra gráfica, que viene siendo de 10x7. Luego con el método 'scatter' distribuimos todos los datos y le damos la leyenda de esos datos con 'label' de nombre 'Synthetic dataset'.
#
# Ahora nombramos los ejes, para X se usa el método 'xlabel' y para Y se usa 'ylabel' y posteriormente el texto con el que se nombrará dicho eje, seguido de 'fontsize' para definir el tamaño del texto. Y para darle un título a la gráfica se usa el método 'title' y se realiza prácticamente lo mismo como lo anterior. Ya para finalizar usamos 'legend' para desplegar la leyenda de los datos en la gráfica y el 'show' para mostrar la gráfica.

# %%
# Visualizamos la generación del dataset sintético
plt.figure(figsize=(10,7))
plt.scatter(x, y, label="Synthetic dataset")
plt.xlabel(r"$x$", fontsize=20)
plt.ylabel("$f_{\mathbf{w}}(x)$", fontsize=20)
plt.title(rf"$f_{{\mathbf{{w}}}}(x) = {true_coeffs[0]} + {true_coeffs[1]} x + \epsilon$, where $\epsilon \sim \mathcal{{N}}(\mu=0, \sigma={noise_std})$", fontsize=20)
plt.legend()
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\m'
# <>:5: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\Jonat\AppData\Local\Temp\ipykernel_7204\3378391424.py:5: SyntaxWarning: invalid escape sequence '\m'
#   plt.ylabel("$f_{\mathbf{w}}(x)$", fontsize=20)

# %% [markdown]
# Empezamos ahora con la división de datos, en donde vamos a tener tanto para los de entrenamiento y prueba, las variables X y Y como se muestra en el código. Normalmente para la división de los datos de entrenamiento se usan el 80% de los datos mientras que para los de prueba el 20% restante, de ahí que se tenga 'test_size=0.2', a su vez, usamos 'random_state=42' para darle una aleatoriedad  única a los datos que se van a usar para entrenamiento y prueba, siendo la semilla de esta aleatoriedad  el número 42, cabe aclarar que no se están modificando los datos, sino el cómo estos mismos se van a repartir, esto con la finalidad de evitar sesgos en nuestro modelo. Y 'shuffle=True' es para que se realice dicha mezcla (aleatoria) de los datos.
#
# Y nuevamente visualizamos en una gráfica cómo se repartieron los datos existentes, en los conjuntos de entrenamiento y de prueba, siendo los datos en azul los de prueba y los rojos los de entrenamiento.

# %%
# Divida los datos en entrenamiento y prueba usando 'train_test_split'
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42, shuffle=True)

# Visualizamos la generación del dataset sintético
plt.figure(figsize=(10,7))
plt.scatter(x, y, label="Testing dataset")
plt.scatter(x_train, y_train, label="Training dataset", color=[1, 0, 0] )
plt.xlabel(r"$x$", fontsize=20)
plt.ylabel("$f_{\mathbf{w}}(x)$", fontsize=20)
plt.title(rf"$f_{{\mathbf{{w}}}}(x) = {true_coeffs[0]} + {true_coeffs[1]} x + \epsilon$, where $\epsilon \sim \mathcal{{N}}(\mu=0, \sigma={noise_std})$", fontsize=20)
plt.legend()
plt.show()
# Out:
# <>:9: SyntaxWarning: invalid escape sequence '\m'
# <>:9: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\Jonat\AppData\Local\Temp\ipykernel_7204\2143441193.py:9: SyntaxWarning: invalid escape sequence '\m'
#   plt.ylabel("$f_{\mathbf{w}}(x)$", fontsize=20)

# %% [markdown]
# Ahora vamos a desarrollar nuestro modelo, para ello necesitamos definir sus características. Hacemos uso de la librería Tensorflor que la definimos como 'tf' y se llama al método 'keras' el cual es una interfaz de usuario intuitiva (API) de alto nivel para desarrollar modelos complejos, en este caso el modelo es del tipo secuencial, lo que quiere decir que es una cadena de capas que tienen una única entrada y salida, es por ello que dentro de esta secuencia en 'layers' tenemos una salida de 1 y la densidad de neuronas es también de 1, lo que quiere decir que solo contamos con una neurona en el modelo.
#
# Compilamos el modelo con el optimizador 'Adam', que es un método de descenso de gradiente para actualizar los pesos y la pérdida 'mse' (error cuadrático medio) es un método para medir que tan bueno es nuestro modelo comparando los datos y la estimación del modelo. Entre más pequeño el valor, menor es el error que está haciendo nuestro modelo y por lo tanto es más preciso a los datos.
#
# Finalmente tenemos mostramos un resumen de las características de nuestro modelo.

# %%
# Construimos el modelo de regresión lineal usando una entrada multiple con una simple neurona
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(1,)),
    tf.keras.layers.Dense(1)
])

# Compilamos el modelo
model.compile(optimizer='adam', loss='mse')
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1)              │             2 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2 (8.00 B)
#  Trainable params: 2 (8.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Una vez configurado el modelo procedemos a entrenarlo con los datos de entrenamiento, y asignándole 'epochs', que en este caso vienen siendo 500 iteraciones, esto para que pueda aprender bien los datos y hacer una buena estimación. Por otro lado tenemos 'batch_size', que es el número de lotes en los que se van a dividir los datos de entrenamiento, y donde el modelo los procesa de adelante hacía atrás, esto antes de actualizar los pesos del mismo.
#
# Batch_size es una indicación para señalar cuántos de esos datos de entrenamiento se van a usar como datos de validación, con estos mismos comparamos qué tan bien nuestro modelo generaliza o predice nuevos datos no vistos. Y ya por último 'verbose' se utiliza para tener una descripción breve del progreso de las épocas del modelo, dando métricas como la perdida (loss), precisión o  la velocidad que le toma cada época. Esto puede ser útil para ver el rendimiento que está teniendo el modelo y en caso de tener una divergencia con los datos, realizar una parada temprana del mismo (early-stopping).
#
# Por último evaluamos el error, comparando los datos de validación con las predicciones del modelo, en otras palabras, se calcula el valor promedio de perdida a partir de los datos de validación.

# %%
# Entrenamos el modelo
model.fit(x_train, y_train, epochs=500, batch_size=10, validation_split=0.10, verbose=1)

# Evaluamos el modelo
loss = model.evaluate(x_test, y_test)
print(f'\nTest Loss: {loss}')
# Out:
# Epoch 1/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1593.8556 - val_loss: 2076.3179
# Epoch 2/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1366.4685 - val_loss: 2030.3469
# Epoch 3/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1456.2964 - val_loss: 1984.0562
# Epoch 4/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1602.9149 - val_loss: 1939.4427
# Epoch 5/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1334.2449 - val_loss: 1895.7915
# Epoch 6/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1540.1631 - val_loss: 1852.5706
# Epoch 7/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1211.4056 - val_loss: 1811.9459
# Epoch 8/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1310.9580 - val_loss: 1770.0106
# Epoch 9/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1160.7339 - val_loss: 1730.3613
# Epoch 10/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1323.6796 - val_loss: 1689.5297
# Epoch 11/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1099.1107 - val_loss: 1651.0347
# Epoch 12/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1170.9174 - val_loss: 1611.9985
# Epoch 13/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1173.5310 - val_loss: 1574.1879
# Epoch 14/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1087.5071 - val_loss: 1538.4491
# Epoch 15/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1258.5076 - val_loss: 1500.9965
# Epoch 16/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1048.6965 - val_loss: 1465.8865
# Epoch 17/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1009.8631 - val_loss: 1429.2352
# Epoch 18/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1073.6525 - val_loss: 1395.1123
# Epoch 19/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 953.8245 - val_loss: 1360.5731
# Epoch 20/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 963.0222 - val_loss: 1327.8615
# Epoch 21/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 963.6083 - val_loss: 1295.6821
# Epoch 22/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1002.4372 - val_loss: 1262.6692
# Epoch 23/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 865.4249 - val_loss: 1230.7559
# Epoch 24/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 934.0489 - val_loss: 1198.2549
# Epoch 25/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 822.2022 - val_loss: 1167.4983
# Epoch 26/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 916.8755 - val_loss: 1135.2722
# Epoch 27/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 798.8854 - val_loss: 1103.7449
# Epoch 28/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 703.2197 - val_loss: 1074.2161
# Epoch 29/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 709.3017 - val_loss: 1044.9996
# Epoch 30/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 759.8489 - val_loss: 1016.6443
# Epoch 31/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 735.4598 - val_loss: 989.4086
# Epoch 32/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss:
500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 89.1619 - val_loss: 96.2252
# Epoch 110/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 91.2080 - val_loss: 93.4471
# Epoch 111/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 87.6761 - val_loss: 90.6560
# Epoch 112/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 80.9078 - val_loss: 88.0269
# Epoch 113/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 92.5394 - val_loss: 85.3956
# Epoch 114/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 82.5973 - val_loss: 82.8512
# Epoch 115/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 92.3765 - val_loss: 80.6857
# Epoch 116/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 85.2388 - val_loss: 78.6117
# Epoch 117/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 88.3122 - val_loss: 76.5644
# Epoch 118/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 96.6390 - val_loss: 74.4980
# Epoch 119/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 92.8204 - val_loss: 72.4436
# Epoch 120/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 95.6269 - val_loss: 70.6265
# Epoch 121/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 90.5744 - val_loss: 68.8266
# Epoch 122/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 89.4599 - val_loss: 67.0594
# Epoch 123/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 68.5793 - val_loss: 65.4065
# Epoch 124/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 63.2395 - val_loss: 63.7308
# Epoch 125/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 65.2438 - val_loss: 62.1082
# Epoch 126/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 84.0041 - val_loss: 60.2657
# Epoch 127/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 78.6565 - val_loss: 58.6081
# Epoch 128/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 77.4157 - val_loss: 56.8513
# Epoch 129/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 79.7070 - val_loss: 55.3267
# Epoch 130/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 71.7805 - val_loss: 54.0600
# Epoch 131/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 72.2625 - val_loss: 52.7974
# Epoch 132/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 77.7060 - val_loss: 51.6432
# Epoch 133/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 76.6162 - val_loss: 50.5458
# Epoch 134/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 80.6181 - val_loss: 49.4822
# Epoch 135/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 66.4332 - val_loss: 48.3975
# Epoch 136/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 67.2042 - val_loss: 47.4341
# Epoch 137/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 75.5094 - val_loss: 46.4388
# Epoch 138/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 70.5881 - val_loss: 45.5955
# Epoch 139/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 70.5307 - val_loss: 44.8052
# Epoch 140/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 72.0491 - val_loss: 43.9892
# Epoch 141/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 59.4555 - val_loss: 43.3579
# Epoch 142/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 79.5607 - val_loss: 42.5381
# Epoch 143/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 62.2987 - val_loss: 41.7199
# Epoch 144/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 72.6223 - val_loss: 40.8525
# Epoch 145/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 68.2333 - val_loss: 40.1128
# Epoch 146/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 78.4795 - val_loss: 39.4696
# Epoch 147/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 77.7469 - val_loss: 38.9022
# Epoch 148/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 65.1170 - val_loss: 38.3245
# Epoch 149/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 71.2125 - val_loss: 37.7493
# Epoch 150/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 58.0108 - val_loss: 37.2650
# Epoch 151/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 69.0862 - val_loss: 36.6483
# Epoch 152/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 65.2103 - val_loss: 36.0622
# Epoch 153/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 57.8279 - val_loss: 35.4864
# Epoch 154/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 64.9816 - val_loss: 34.9135
# Epoch 155/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 72.2071 - val_loss: 34.4556
# Epoch 156/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 59.4142 - val_loss: 34.0906
# Epoch 157/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 66.0463 - val_loss: 33.6994
# Epoch 158/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 57.4826 - val_loss: 33.4191
# Epoch 159/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 59.4278 - val_loss: 33.0858
# Epoch 160/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 61.3928 - val_loss: 32.8247
# Epoch 161/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 60.6290 - val_loss: 32.4622
# Epoch 162/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 69.5318 - val_loss: 32.0268
# Epoch 163/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 64.4972 - val_loss: 31.8285
# Epoch 164/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 67.2623 - val_loss: 31.6590
# Epoch 165/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 62.7358 - val_loss: 31.4722
# Epoch 166/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 64.8404 - val_loss: 31.2005
# Epoch 167/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 56.8619 - val_loss: 30.7876
# Epoch 168/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 65.8109 - val_loss: 30.5794
# Epoch 169/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 59.9905 - val_loss: 30.3340
# Epoch 170/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 69.8792 - val_loss: 29.9666
# Epoch 171/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 63.0024 - val_loss: 29.7804
# Epoch 172/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 62.2205 - val_loss: 29.6142
# Epoch 173/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 60.8158 - val_loss: 29.3639
# Epoch 174/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 67.3285 - val_loss: 29.2085
# Epoch 175/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 64.1367 - val_loss: 28.9495
# Epoch 176/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 54.1752 - val_loss: 28.7557
# Epoch 177/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 54.7597 - val_loss: 28.5936
# Epoch 178/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 52.4383 - val_loss: 28.4957
# Epoch 179/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 68.6727 - val_loss: 28.3095
# Epoch 180/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 66.7750 - val_loss: 28.2030
# Epoch 181/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 68.6895 - val_loss: 28.0431
# Epoch 182/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 72.3327 - val_loss: 27.8577
# Epoch 183/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 60.1038 - val_loss: 27.6239
# Epoch 184/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 65.8211 - val_loss: 27.3914
# Epoch 185/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 64.6457 - val_loss: 27.3353
# Epoch 186/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 58.7038 - val_loss: 27.1643
# Epoch 187/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 60.4816 - val_loss: 27.0185
# Epoch 188/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 53.4674 - val_loss: 26.8686
# Epoch 189/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 61.9424 - val_loss: 26.7672
# Epoch 190/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 67.9503 - val_loss: 26.7254
# Epoch 191/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 61.2370 - val_loss: 26.6631
# Epoch 192/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 67.9971 - val_loss: 26.5261
# Epoch 193/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 51.0213 - val_loss: 26.4595
# Epoch 194/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 56.2530 - val_loss: 26.3650
# Epoch 195/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 61.1964 - val_loss: 26.2073
# Epoch 196/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 65.4476 - val_loss: 26.1138
# Epoch 197/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 49.0166 - val_loss: 25.9754
# Epoch 198/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 70.9639 - val_loss: 25.8103
# Epoch 199/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 59.4100 - val_loss: 25.6357
# Epoch 200/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 54.7953 - val_loss: 25.4926
# Epoch 201/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 61.1464 - val_loss: 25.3047
# Epoch 202/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 65.6312 - val_loss: 25.0516
# Epoch 203/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 70.0317 - val_loss: 24.9289
# Epoch 204/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 60.2027 - val_loss: 24.9030
# Epoch 205/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 60.7650 - val_loss: 24.8647
# Epoch 206/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 56.7359 - val_loss: 24.8633
# Epoch 207/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 65.8952 - val_loss: 24.7945
# Epoch 208/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 52.8512 - val_loss: 24.7582
# Epoch 209/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 67.3013 - val_loss: 24.6737
# Epoch 210/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 52.0165 - val_loss: 24.5499
# Epoch 211/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 69.4361 - val_loss: 24.4842
# Epoch 212/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 61.9366 - val_loss: 24.3865
# Epoch 213/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 66.5007 - val_loss: 24.3166
# Epoch 214/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 53.5596 - val_loss: 24.2391
# Epoch 215/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 67.0515 - val_loss: 24.2194
# Epoch 216/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 65.6904 - val_loss: 24.2141
# Epoch 217/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 69.7616 - val_loss: 24.1273
# Epoch 218/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 69.9678 - val_loss: 24.1605
# Epoch 219/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 64.7252 - val_loss: 24.1515
# Epoch 220/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 56.2473 - val_loss: 24.1106
# Epoch 221/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 58.0801 - val_loss: 24.0589
# Epoch 222/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 61.2454 - val_loss: 24.0186
# Epoch 223/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 70.9173 - val_loss: 24.0604
# Epoch 224/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 57.1157 - val_loss: 24.1036
# Epoch 225/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 57
500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 57.6328 - val_loss: 22.6473
# Epoch 402/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 59.7390 - val_loss: 22.7519
# Epoch 403/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 50.6479 - val_loss: 22.8082
# Epoch 404/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 61.6143 - val_loss: 22.6793
# Epoch 405/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 56.2006 - val_loss: 22.7522
# Epoch 406/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 59.6441 - val_loss: 22.5307
# Epoch 407/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 56.3091 - val_loss: 22.3743
# Epoch 408/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 57.5093 - val_loss: 22.3378
# Epoch 409/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 58.9821 - val_loss: 22.2542
# Epoch 410/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 67.0561 - val_loss: 22.1047
# Epoch 411/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 55.7801 - val_loss: 21.8773
# Epoch 412/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 60.2175 - val_loss: 21.9311
# Epoch 413/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 60.9090 - val_loss: 21.9336
# Epoch 414/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 53.8883 - val_loss: 22.0648
# Epoch 415/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 44.2615 - val_loss: 22.0990
# Epoch 416/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 59.9018 - val_loss: 22.0727
# Epoch 417/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 59.6081 - val_loss: 21.9219
# Epoch 418/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 63.4850 - val_loss: 21.8066
# Epoch 419/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 66.7183 - val_loss: 21.8274
# Epoch 420/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 63.6398 - val_loss: 21.8555
# Epoch 421/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 59.1869 - val_loss: 21.8422
# Epoch 422/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.4096 - val_loss: 21.7041
# Epoch 423/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 59.3915 - val_loss: 21.5303
# Epoch 424/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 55.1179 - val_loss: 21.3888
# Epoch 425/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 57.1716 - val_loss: 21.3231
# Epoch 426/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 58.6413 - val_loss: 21.2552
# Epoch 427/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 62.5595 - val_loss: 21.4366
# Epoch 428/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 62.0347 - val_loss: 21.5225
# Epoch 429/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 54.6451 - val_loss: 21.4644
# Epoch 430/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 51.6205 - val_loss: 21.4205
# Epoch 431/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 50.0055 - val_loss: 21.4373
# Epoch 432/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 59.6521 - val_loss: 21.4092
# Epoch 433/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 61.8244 - val_loss: 21.3570
# Epoch 434/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 55.2272 - val_loss: 21.3734
# Epoch 435/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 63.2327 - val_loss: 21.3756
# Epoch 436/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 58.2119 - val_loss: 21.3327
# Epoch 437/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 56.2400 - val_loss: 21.2604
# Epoch 438/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 52.7410 - val_loss: 21.0649
# Epoch 439/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 59.0767 - val_loss: 21.0867
# Epoch 440/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 53.8640 - val_loss: 20.9690
# Epoch 441/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 62.0791 - val_loss: 20.8528
# Epoch 442/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 54.4844 - val_loss: 20.9738
# Epoch 443/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 55.1093 - val_loss: 21.0294
# Epoch 444/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 63.5503 - val_loss: 21.2558
# Epoch 445/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 58.8073 - val_loss: 21.3643
# Epoch 446/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 56.1229 - val_loss: 21.2354
# Epoch 447/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 59.2456 - val_loss: 21.2148
# Epoch 448/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 60.0838 - val_loss: 21.2130
# Epoch 449/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 57.7903 - val_loss: 21.3763
# Epoch 450/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 54.2005 - val_loss: 21.5269
# Epoch 451/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 60.3924 - val_loss: 21.5394
# Epoch 452/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 63.7487 - val_loss: 21.4917
# Epoch 453/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 55.7484 - val_loss: 21.4877
# Epoch 454/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 60.5625 - val_loss: 21.5455
# Epoch 455/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 71.6089 - val_loss: 21.3472
# Epoch 456/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 52.3974 - val_loss: 21.2055
# Epoch 457/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 46.8195 - val_loss: 20.9412
# Epoch 458/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 62.5241 - val_loss: 20.8646
# Epoch 459/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 62.5251 - val_loss: 20.7373
# Epoch 460/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 52.6495 - val_loss: 20.7385
# Epoch 461/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 50.0682 - val_loss: 20.7514
# Epoch 462/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 64.1191 - val_loss: 20.5935
# Epoch 463/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 52.5682 - val_loss: 20.5591
# Epoch 464/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 51.8716 - val_loss: 20.7525
# Epoch 465/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 64.6647 - val_loss: 20.6915
# Epoch 466/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.6091 - val_loss: 20.6252
# Epoch 467/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 56.0704 - val_loss: 20.5555
# Epoch 468/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 59.3162 - val_loss: 20.5677
# Epoch 469/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 58.3905 - val_loss: 20.7863
# Epoch 470/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 48.6777 - val_loss: 20.9040
# Epoch 471/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 59.4403 - val_loss: 20.8775
# Epoch 472/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 63.8660 - val_loss: 20.6504
# Epoch 473/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 66.0545 - val_loss: 20.6286
# Epoch 474/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 60.1035 - val_loss: 20.6182
# Epoch 475/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 63.5740 - val_loss: 20.4343
# Epoch 476/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 60.5900 - val_loss: 20.4059
# Epoch 477/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 50.3950 - val_loss: 20.5704
# Epoch 478/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 56.9339 - val_loss: 20.6612
# Epoch 479/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 57.1940 - val_loss: 20.9634
# Epoch 480/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 58.5719 - val_loss: 21.0801
# Epoch 481/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 61.9988 - val_loss: 21.0310
# Epoch 482/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 58.5657 - val_loss: 20.9808
# Epoch 483/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 51.9523 - val_loss: 21.1798
# Epoch 484/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 64.1150 - val_loss: 21.3805
# Epoch 485/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 65.4627 - val_loss: 21.1822
# Epoch 486/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 59.2189 - val_loss: 21.1805
# Epoch 487/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 67.0314 - val_loss: 21.0643
# Epoch 488/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 53.2244 - val_loss: 20.9497
# Epoch 489/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 59.1340 - val_loss: 20.8370
# Epoch 490/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 54.0843 - val_loss: 20.7226
# Epoch 491/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 48.0349 - val_loss: 20.7394
# Epoch 492/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 57.4875 - val_loss: 20.7376
# Epoch 493/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 58.4484 - val_loss: 20.6078
# Epoch 494/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 63.5660 - val_loss: 20.5112
# Epoch 495/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 50.9651 - val_loss: 20.5227
# Epoch 496/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 59.5844 - val_loss: 20.4763
# Epoch 497/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 61.2853 - val_loss: 20.9427
# Epoch 498/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 54.5639 - val_loss: 21.5012
# Epoch 499/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 52.5400 - val_loss: 22.0285
# Epoch 500/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 55.1900 - val_loss: 22.3380
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 49.5319
#
# Test Loss: 49.531917572021484

# %% [markdown]
# Extraemos los pesos de las capas de nuestro modelo. y al solo contar con una capa, ya que nuestra red es simple, entonces solo tomamos esa, que viene siendo 'layers[0]' y ya la empezamos a obtener con el método 'get_weights'.
#
# Imprimimos el peso (weights[0]) y el sesgo (weights[1]). Los pesos determinan la influencia que tienen los datos de entrada en el producto final, mientras que los sesgos son unidades independientes que se agregan a los datos, ajustando el flujo de la red para dar un resultado más preciso.

# %%
# Imprimimos los pesos del modelo entrenado
weights = model.layers[0].get_weights()
print(f"Weights [w1]: {weights[0]}")
print(f"Biases [w0]: {weights[1]}")
# Out:
# Weights [w1]: [[1.11569]]
# Biases [w0]: [1.7510982]

# %% [markdown]
# Una vez  entrenado el modelo, y asegurarnos de que el progreso del entrenamiento no haya tenido inconvenientes, ponemos aprueba ahora nuestro modelo resultante y comparamos las predicciones con los datos reales.

# %%
# Hacemos predicciones
y_pred = model.predict(x_test)
y_pred_train = model.predict(x_train)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 975us/step

# %% [markdown]
# Graficamos esta comparativa, donde nombramos los datos de entrenamiento como 'Training data', mientras a la predicciones la nombramos como 'Model', con un 'linewidth' de 3 y en color rojo (1,0,0). A su vez nombramos los ejes con un 'fontsize' de 20 y terminamos mostrando la gráfica.
#
# Podemos observar que nuestro modelo creado si desarrolla de manera correcta las estimaciones de los datos, ya que se ajusta muy bien a las mismas, lo que nos da un muy buen modelo para esta tarea de regresión lineal, usando una red neuronal simple.

# %%
# Graficamos los resultados
plt.figure(figsize=(10, 7))

plt.scatter(x_train, y_train, label="Training data")
plt.plot(x_train, y_pred_train, label="Model", linewidth=3, color=[1,0,0])
plt.xlabel(r'$x$', fontsize=20)
plt.ylabel("$\hat{f}_{\mathbf{w}}(x)$", fontsize=20)
plt.legend();
# Out:
# <>:7: SyntaxWarning: invalid escape sequence '\h'
# <>:7: SyntaxWarning: invalid escape sequence '\h'
# C:\Users\Jonat\AppData\Local\Temp\ipykernel_7204\1179736667.py:7: SyntaxWarning: invalid escape sequence '\h'
#   plt.ylabel("$\hat{f}_{\mathbf{w}}(x)$", fontsize=20)

# %% [markdown]
# ### **Conclusiones**
#
# La actividad se me hace interesante, sobre todo la parte del desarrolllo del modelo de nuestra red neuronal simple. Es importante conocer toda la estructura del código, comenzando con las librerías, definición de las funciones a usar, sus variables o parámetros de entrada y salida, y luego ya comenzar con el desarrollo del modelo, como lo es la división de los datos, asignar las características que manejará el modelo, entrenar el modelo y finalmente probar su funcionamiento.
#
# Por experiencia en python, yo ya conocía algunas cosas, como la importación de librerías, realizar funciones, y generar gráficas en base a datos, así como la división de datos de entrenamiento y de prueba, y probado otros tipos de modelos como lo son el PCA, KNN, K-Means o Clustering, pero esta parte nueva que es el uso o desarrollo de redes neuronales, que es este caso solo es una simple neurona, se me hizo llamativo el ver sus características y el cómo tú  mismo puedes configurar el modelo, dependiendo de la aplicación me imagino que se usan diferentes estructuras, procesamientos, optimizadores y funciones de costo, pero está muy padre el ver cómo con esto y ver su progreso en las épocas o interacciones, genera diferentes resultados según lo que hayas puesto, y que dependiendo de eso puede generar buenos o malos resultados, y viéndolo de esa forma, también nosotros estarías aprendiendo, iterando entre configuración y configuración a desarrollar redes neuronales y tener una mejor noción de lo que implica el uso de estas herramientas poderosas.

# %% [markdown]
# ### **Referencias**
#
# * ChatGPT. (2024, agosto 26). Explicación del Modelo Keras: https://chatgpt.com/c/e50b0a86-253b-4607-966f-b55f6511e4bb
# * ChatGPT. (2024, agosto 27). Batch Size Validation Verbose:https://chatgpt.com/c/41d5eb82-23af-4f7a-aa91-f38dfd20a59c
# * Equipo editorial de IONOS. (8 de Octubre de 2020). Keras: biblioteca de código abierto para crear redes neuronales. Obtenido de IONOS: https://www.ionos.mx/digitalguide/online-marketing/marketing-para-motores-de-busqueda/que-es-keras/
# * Keras. (s.f.). Adam. Obtenido de Keras: https://keras.io/api/optimizers/adam/
